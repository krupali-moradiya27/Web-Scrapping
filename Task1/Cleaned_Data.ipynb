# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import os

# Provide the full path to the file
#file_path = os.path.join(r"C:\Users\princ\Desktop\PACE Docs\INSPIRE\Micro-Internship\BRITISH AIRWAYS\Airline Reviews\data", "skytrax_reviews.csv")
file_path = r"C:\Users\princ\Desktop\PACE Docs\INSPIRE\Micro-Internship\BRITISH AIRWAYS\Airline Reviews\Web Scrapper_Task-1\data\skytrax_reviews.csv
df = pd.read_csv(file_path)

# View the first few rows of the data
print(df.head())  # Check if data is loaded

# Check for missing values
print(df.isnull().sum())

# Drop rows with missing values
df.dropna(inplace=True)
print(df.shape)  # Check how many rows are left

# Remove duplicates
df.drop_duplicates(inplace=True)
print(df.shape)  # Check how many rows are left after dropping duplicates

# Check if 'review_text' column exists
print(df.columns)

# Convert the 'text' column to lowercase
df['review_text'] = df['review_text'].apply(lambda x: x.lower())
print(df['review_text'].head())  # Check the text after conversion to lowercase

# ... (other steps)

# Check final result before saving
print(df.head())

# Save the cleaned data to a new CSV file
df.to_csv('cleaned_data.csv', index=False)


# # View the first few rows of the data
# print(df.head())

# # Check for missing values
# print(df.isnull().sum())

# # Drop rows with missing values
# df.dropna(inplace=True)

# # Remove duplicates
# df.drop_duplicates(inplace=True)

# # Convert the 'text' column to lowercase
# df['review_text'] = df['review_text'].apply(lambda x: x.lower())

# # Remove special characters and numbers
# df['review_text'] = df['review_text'].apply(lambda x: re.sub(r'[^a-zA-Z]', ' ', x))

# # Tokenize the text
# df['review_text'] = df['review_text'].apply(lambda x: word_tokenize(x))

# # Remove stopwords
# nltk.download('stopwords')
# stop_words = set(stopwords.words('english'))
# df['review_text'] = df['review_text'].apply(lambda x: [word for word in x if word not in stop_words])

# # Lemmatize the words
# nltk.download('wordnet')
# lemmatizer = WordNetLemmatizer()
# df['review_text'] = df['review_text'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# # Join the tokens back into a string
# df['review_text'] = df['review_text'].apply(lambda x: ' '.join(x))

# # View the cleaned data
# print(df.head())

# # Save the cleaned data to a new CSV file
# df.to_csv('cleaned_data.csv', index=False)
# Out:
#   Input In [4]
#     file_path = r"C:\Users\princ\Desktop\PACE Docs\INSPIRE\Micro-Internship\BRITISH AIRWAYS\Airline Reviews\Web Scrapper_Task-1\data\skytrax_reviews.csv
#                                                                                                                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
df.head()
